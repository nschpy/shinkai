# %%
from datasets import load_dataset

# %%
# Загружаем только Swift-код
dataset = load_dataset("bigcode/the-stack-dedup", data_dir="data/swift", split="train")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Загружаем только Swift-код
# ----> 2 dataset = load_dataset("bigcode/the-stack-dedup", data_dir="data/swift", split="train")
#
# File ~/Library/Caches/pypoetry/virtualenvs/shinkai-HQP2GmPL-py3.12/lib/python3.12/site-packages/datasets/load.py:2084, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2081     return builder_instance.as_streaming_dataset(split=split)
#    2083 # Download and prepare data
# -> 2084 builder_instance.download_and_prepare(
#    2085     download_config=download_config,
#    2086     download_mode=download_mode,
#    2087     verification_mode=verification_mode,
# ...
